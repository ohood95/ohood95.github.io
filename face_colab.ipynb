# %% [markdown]
# <a href="https://colab.research.google.com/github/ohood95/ohood95.github.io/blob/master/face_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Face Emotion Training (Google Colab)
# Run the setup then edit dataset_path.

# %%
# !pip -q install tensorflow

# %%
import kagglehub

# Download latest version
dataset_path = kagglehub.dataset_download("msambare/fer2013")

print(dataset_path)
# Out:
# Using Colab cache for faster access to the 'fer2013' dataset.
# /kaggle/input/fer2013

# %%
import os

for root, dirs, files in os.walk("/kaggle/input/fer2013"):
    print(root)
# Out:
# /kaggle/input/fer2013
# /kaggle/input/fer2013/test
# /kaggle/input/fer2013/test/surprise
# /kaggle/input/fer2013/test/fear
# /kaggle/input/fer2013/test/angry
# /kaggle/input/fer2013/test/neutral
# /kaggle/input/fer2013/test/sad
# /kaggle/input/fer2013/test/disgust
# /kaggle/input/fer2013/test/happy
# /kaggle/input/fer2013/train
# /kaggle/input/fer2013/train/surprise
# /kaggle/input/fer2013/train/fear
# /kaggle/input/fer2013/train/angry
# /kaggle/input/fer2013/train/neutral
# /kaggle/input/fer2013/train/sad
# /kaggle/input/fer2013/train/disgust
# /kaggle/input/fer2013/train/happy

# %%
# Change this path to your dataset in Google Drive
train_path = "/kaggle/input/fer2013/train"
test_path = "/kaggle/input/fer2013/test"

# %%
import os

print(os.path.exists("/kaggle/input/fer2013"))
print(os.path.exists("/kaggle/input/fer2013/train"))
# Out:
# True
# True

# %%
import os

train_path = "/kaggle/input/fer2013/train"
test_path = "/kaggle/input/fer2013/test"

print("Train:", train_path)
print("Exists:", os.path.exists(train_path))

print("Test:", test_path)
print("Exists:", os.path.exists(test_path))
# Out:
# Train: /kaggle/input/fer2013/train
# Exists: True
# Test: /kaggle/input/fer2013/test
# Exists: True

# %%
# !pip install -q kagglehub

import kagglehub

path = kagglehub.dataset_download("msambare/fer2013")
print(path)
# Out:
# Using Colab cache for faster access to the 'fer2013' dataset.
# /kaggle/input/fer2013

# %%
import os

print(os.path.exists(train_path))
print(os.path.exists(test_path))
# Out:
# True
# True

# %%
import os

print(train_path)
print(os.path.exists(train_path))

print(test_path)
print(os.path.exists(test_path))
# Out:
# /kaggle/input/fer2013/train
# True
# /kaggle/input/fer2013/test
# True

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import matplotlib.pyplot as plt
import numpy as np
import os


# dataset_path overridden above
img_height, img_width = 48, 48
batch_size = 32
epochs = 50


emotions = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']


train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.2,
    shear_range=0.1,
    fill_mode='nearest',
    validation_split=0.2
)


train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    color_mode='grayscale',
    class_mode='categorical',
    subset='training',
    shuffle=True
)


validation_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    color_mode='grayscale',
    class_mode='categorical',
    subset='validation',
    shuffle=False
)




model = Sequential()


from tensorflow.keras import Input

model = Sequential()

# Block 1
model.add(Input(shape=(img_height, img_width, 1)))

model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())

model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))


# Block 2
model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())

model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))


# Block 3
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())

model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))


# Block 4
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))


# Classifier
model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(7, activation='softmax'))


model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)


model.summary()


callbacks = [
    ReduceLROnPlateau(
        monitor='val_accuracy',
        factor=0.5,
        patience=5,
        min_lr=0.00001
    ),
    EarlyStopping(
        monitor='val_loss',
        patience=15,
        restore_best_weights=True
    )
]


history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    callbacks=callbacks
)


model.save('facial_expression_model.h5')
print("done")


def plot_training_history(history):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))


    ax1.plot(history.history['accuracy'], label='Training Accuracy')
    ax1.plot(history.history['val_accuracy'], label='Validation Accuracy')
    ax1.set_title('Model Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Accuracy')
    ax1.legend()


    ax2.plot(history.history['loss'], label='Training Loss')
    ax2.plot(history.history['val_loss'], label='Validation Loss')
    ax2.set_title('Model Loss')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss')
    ax2.legend()

    plt.tight_layout()
    plt.savefig('training_history.png')
    plt.show()

plot_training_history(history)


print("\n model acc:")
val_loss, val_accuracy = model.evaluate(validation_generator)
print(f"Final scc: {val_accuracy*100:.2f}%")


def predict_emotion(image_path, model):
    from tensorflow.keras.preprocessing import image
    img = image.load_img(image_path, target_size=(img_height, img_width), color_mode='grayscale')
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0

    prediction = model.predict(img_array)
    emotion_index = np.argmax(prediction)
    confidence = np.max(prediction)

    return emotions[emotion_index], confidence
# Out:
# Found 22968 images belonging to 7 classes.
# Found 5741 images belonging to 7 classes.
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 48, 48, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 48, 48, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 48, 48, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 24, 24, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 24, 24, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 24, 24, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 24, 24, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 12, 12, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 12, 12, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 12, 12, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 12, 12, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 6, 6, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 6, 6, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 3, 3, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 3, 3, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2304)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,900,775 (7.25 MB)
#  Trainable params: 1,897,831 (7.24 MB)
#  Non-trainable params: 2,944 (11.50 KB)
# Epoch 1/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 217s 293ms/step - accuracy: 0.2187 - loss: 2.1815 - val_accuracy: 0.2734 - val_loss: 1.7939 - learning_rate: 0.0010
# Epoch 2/50
#   1/717 ━━━━━━━━━━━━━━━━━━━━ 2:13 187ms/step - accuracy: 0.2500 - loss: 1.8385
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.2500 - loss: 1.8385 - val_accuracy: 0.2697 - val_loss: 1.7945 - learning_rate: 0.0010
# Epoch 3/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 145s 202ms/step - accuracy: 0.2938 - loss: 1.7616 - val_accuracy: 0.3347 - val_loss: 1.6603 - learning_rate: 0.0010
# Epoch 4/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.3438 - loss: 1.6986 - val_accuracy: 0.3341 - val_loss: 1.6595 - learning_rate: 0.0010
# Epoch 5/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 146s 204ms/step - accuracy: 0.3631 - loss: 1.6169 - val_accuracy: 0.3891 - val_loss: 1.5674 - learning_rate: 0.0010
# Epoch 6/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.3750 - loss: 1.6511 - val_accuracy: 0.3932 - val_loss: 1.5813 - learning_rate: 0.0010
# Epoch 7/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 145s 202ms/step - accuracy: 0.4182 - loss: 1.4988 - val_accuracy: 0.4476 - val_loss: 1.4191 - learning_rate: 0.0010
# Epoch 8/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.5312 - loss: 1.3694 - val_accuracy: 0.4623 - val_loss: 1.4080 - learning_rate: 0.0010
# Epoch 9/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 145s 202ms/step - accuracy: 0.4601 - loss: 1.4050 - val_accuracy: 0.4951 - val_loss: 1.3153 - learning_rate: 0.0010
# Epoch 10/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.4688 - loss: 1.3764 - val_accuracy: 0.4939 - val_loss: 1.3164 - learning_rate: 0.0010
# Epoch 11/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 147s 205ms/step - accuracy: 0.4812 - loss: 1.3459 - val_accuracy: 0.5169 - val_loss: 1.2723 - learning_rate: 0.0010
# Epoch 12/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.5625 - loss: 1.3171 - val_accuracy: 0.5159 - val_loss: 1.2756 - learning_rate: 0.0010
# Epoch 13/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 147s 205ms/step - accuracy: 0.4988 - loss: 1.3158 - val_accuracy: 0.5197 - val_loss: 1.2496 - learning_rate: 0.0010
# Epoch 14/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.5938 - loss: 1.2337 - val_accuracy: 0.5194 - val_loss: 1.2537 - learning_rate: 0.0010
# Epoch 15/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 147s 205ms/step - accuracy: 0.5169 - loss: 1.2790 - val_accuracy: 0.5405 - val_loss: 1.2152 - learning_rate: 0.0010
# Epoch 16/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.4062 - loss: 1.2552 - val_accuracy: 0.5395 - val_loss: 1.2213 - learning_rate: 0.0010
# Epoch 17/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 146s 204ms/step - accuracy: 0.5291 - loss: 1.2443 - val_accuracy: 0.5552 - val_loss: 1.1781 - learning_rate: 0.0010
# Epoch 18/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.5000 - loss: 1.2649 - val_accuracy: 0.5628 - val_loss: 1.1645 - learning_rate: 0.0010
# Epoch 19/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 194s 209ms/step - accuracy: 0.5363 - loss: 1.2252 - val_accuracy: 0.5457 - val_loss: 1.1868 - learning_rate: 0.0010
# Epoch 20/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.5625 - loss: 1.0195 - val_accuracy: 0.5436 - val_loss: 1.1833 - learning_rate: 0.0010
# Epoch 21/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 149s 207ms/step - accuracy: 0.5456 - loss: 1.2066 - val_accuracy: 0.5585 - val_loss: 1.1734 - learning_rate: 0.0010
# Epoch 22/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.4062 - loss: 1.4905 - val_accuracy: 0.5546 - val_loss: 1.1822 - learning_rate: 0.0010
# Epoch 23/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 189s 205ms/step - accuracy: 0.5511 - loss: 1.1864 - val_accuracy: 0.5288 - val_loss: 1.2420 - learning_rate: 0.0010
# Epoch 24/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.5312 - loss: 1.1743 - val_accuracy: 0.5271 - val_loss: 1.2418 - learning_rate: 5.0000e-04
# Epoch 25/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 146s 204ms/step - accuracy: 0.5726 - loss: 1.1429 - val_accuracy: 0.5749 - val_loss: 1.1352 - learning_rate: 5.0000e-04
# Epoch 26/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.5312 - loss: 1.4045 - val_accuracy: 0.5679 - val_loss: 1.1362 - learning_rate: 5.0000e-04
# Epoch 27/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 149s 207ms/step - accuracy: 0.5812 - loss: 1.1116 - val_accuracy: 0.5815 - val_loss: 1.1029 - learning_rate: 5.0000e-04
# Epoch 28/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.6562 - loss: 1.0366 - val_accuracy: 0.5834 - val_loss: 1.1103 - learning_rate: 5.0000e-04
# Epoch 29/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 149s 208ms/step - accuracy: 0.5826 - loss: 1.1092 - val_accuracy: 0.5946 - val_loss: 1.0867 - learning_rate: 5.0000e-04
# Epoch 30/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.5938 - loss: 0.9724 - val_accuracy: 0.5997 - val_loss: 1.0825 - learning_rate: 5.0000e-04
# Epoch 31/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 147s 205ms/step - accuracy: 0.5882 - loss: 1.0854 - val_accuracy: 0.5957 - val_loss: 1.0715 - learning_rate: 5.0000e-04
# Epoch 32/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.4688 - loss: 1.4703 - val_accuracy: 0.5934 - val_loss: 1.0695 - learning_rate: 5.0000e-04
# Epoch 33/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 147s 206ms/step - accuracy: 0.5937 - loss: 1.0808 - val_accuracy: 0.5808 - val_loss: 1.0971 - learning_rate: 5.0000e-04
# Epoch 34/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.7812 - loss: 0.7589 - val_accuracy: 0.5864 - val_loss: 1.0851 - learning_rate: 5.0000e-04
# Epoch 35/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 149s 207ms/step - accuracy: 0.5950 - loss: 1.0767 - val_accuracy: 0.6030 - val_loss: 1.0656 - learning_rate: 5.0000e-04
# Epoch 36/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.6250 - loss: 1.0259 - val_accuracy: 0.5992 - val_loss: 1.0633 - learning_rate: 5.0000e-04
# Epoch 37/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 186s 201ms/step - accuracy: 0.6025 - loss: 1.0617 - val_accuracy: 0.5988 - val_loss: 1.0541 - learning_rate: 5.0000e-04
# Epoch 38/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.4062 - loss: 1.3202 - val_accuracy: 0.6058 - val_loss: 1.0599 - learning_rate: 5.0000e-04
# Epoch 39/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 148s 206ms/step - accuracy: 0.6013 - loss: 1.0609 - val_accuracy: 0.6006 - val_loss: 1.0483 - learning_rate: 5.0000e-04
# Epoch 40/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.6562 - loss: 0.8549 - val_accuracy: 0.6013 - val_loss: 1.0526 - learning_rate: 5.0000e-04
# Epoch 41/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 146s 203ms/step - accuracy: 0.6105 - loss: 1.0476 - val_accuracy: 0.5882 - val_loss: 1.0771 - learning_rate: 5.0000e-04
# Epoch 42/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.5625 - loss: 1.0961 - val_accuracy: 0.5868 - val_loss: 1.0924 - learning_rate: 5.0000e-04
# Epoch 43/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 146s 204ms/step - accuracy: 0.6122 - loss: 1.0358 - val_accuracy: 0.6068 - val_loss: 1.0481 - learning_rate: 5.0000e-04
# Epoch 44/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.7500 - loss: 0.8427 - val_accuracy: 0.6063 - val_loss: 1.0549 - learning_rate: 5.0000e-04
# Epoch 45/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 145s 202ms/step - accuracy: 0.6124 - loss: 1.0352 - val_accuracy: 0.6095 - val_loss: 1.0399 - learning_rate: 5.0000e-04
# Epoch 46/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.5000 - loss: 1.1184 - val_accuracy: 0.6013 - val_loss: 1.0547 - learning_rate: 5.0000e-04
# Epoch 47/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 144s 201ms/step - accuracy: 0.6150 - loss: 1.0334 - val_accuracy: 0.6142 - val_loss: 1.0320 - learning_rate: 5.0000e-04
# Epoch 48/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.5312 - loss: 1.3006 - val_accuracy: 0.6109 - val_loss: 1.0364 - learning_rate: 5.0000e-04
# Epoch 49/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 143s 199ms/step - accuracy: 0.6165 - loss: 1.0267 - val_accuracy: 0.6163 - val_loss: 1.0150 - learning_rate: 5.0000e-04
# Epoch 50/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.4062 - loss: 1.5150 - val_accuracy: 0.6217 - val_loss: 1.0124 - learning_rate: 5.0000e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# done
#  model acc:
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.6231 - loss: 1.0164
# Final scc: 62.31%

# %%
val_loss, val_accuracy = model.evaluate(validation_generator)
print(f"Final acc: {val_accuracy*100:.2f}%")
# Out:
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 11s 64ms/step - accuracy: 0.6206 - loss: 1.0080
# Final acc: 62.06%

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# إعادة المؤشر لأول البيانات
validation_generator.reset()

# التنبؤ
pred = model.predict(validation_generator)

# الفئة المتوقعة
y_pred = np.argmax(pred, axis=1)

# الفئة الحقيقية
y_true = validation_generator.classes

# أسماء الفئات
class_names = list(validation_generator.class_indices.keys())

print("="*60)
print("CLASSIFICATION REPORT")
print("="*60)

print(classification_report(
    y_true,
    y_pred,
    target_names=class_names,
    digits=4
))
# Out:
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step
# ============================================================
# CLASSIFICATION REPORT
# ============================================================
#               precision    recall  f1-score   support
#
#        angry     0.5615    0.5031    0.5307       799
#      disgust     0.5814    0.2874    0.3846        87
#         fear     0.5148    0.2552    0.3412       819
#        happy     0.8008    0.8663    0.8322      1443
#      neutral     0.5239    0.7180    0.6058       993
#          sad     0.4945    0.5155    0.5048       966
#     surprise     0.7002    0.7145    0.7073       634
#
#     accuracy                         0.6184      5741
#    macro avg     0.5967    0.5514    0.5581      5741
# weighted avg     0.6128    0.6184    0.6054      5741

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8,6))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=class_names,
    yticklabels=class_names
)

plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import accuracy_score

acc = accuracy_score(y_true, y_pred)

print(f"\nOverall Accuracy : {acc*100:.2f}%")
# Out:
# Overall Accuracy : 61.84%

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

print(f"Precision : {precision_score(y_true,y_pred,average='weighted'):.4f}")
print(f"Recall    : {recall_score(y_true,y_pred,average='weighted'):.4f}")
print(f"F1-score  : {f1_score(y_true,y_pred,average='weighted'):.4f}")
# Out:
# Precision : 0.6128
# Recall    : 0.6184
# F1-score  : 0.6054

# %%
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_curve,
    auc
)

from sklearn.preprocessing import label_binarize

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
validation_generator.reset()

predictions = model.predict(validation_generator)

y_pred = np.argmax(predictions, axis=1)
y_true = validation_generator.classes

class_names = list(validation_generator.class_indices.keys())
# Out:
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step

# %%
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='weighted')
recall = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')

print("="*60)
print("MODEL PERFORMANCE")
print("="*60)

print(f"Accuracy : {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1-score : {f1:.4f}")
# Out:
# ============================================================
# MODEL PERFORMANCE
# ============================================================
# Accuracy : 0.6166
# Precision: 0.6117
# Recall   : 0.6166
# F1-score : 0.6043

# %%
print("\n")
print("="*60)
print("CLASSIFICATION REPORT")
print("="*60)

print(classification_report(
    y_true,
    y_pred,
    target_names=class_names,
    digits=4
))
# Out:
# ============================================================
# CLASSIFICATION REPORT
# ============================================================
#               precision    recall  f1-score   support
#
#        angry     0.5583    0.5031    0.5293       799
#      disgust     0.6047    0.2989    0.4000        87
#         fear     0.5264    0.2674    0.3547       819
#        happy     0.7935    0.8683    0.8293      1443
#      neutral     0.5152    0.6989    0.5932       993
#          sad     0.4904    0.5010    0.4956       966
#     surprise     0.7119    0.7287    0.7202       634
#
#     accuracy                         0.6166      5741
#    macro avg     0.6001    0.5523    0.5603      5741
# weighted avg     0.6117    0.6166    0.6043      5741

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8,7))

sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=class_names,
    yticklabels=class_names
)

plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")

plt.tight_layout()

plt.savefig("confusion_matrix.png",dpi=300)

plt.show()

# %%
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

plt.figure(figsize=(8,7))

sns.heatmap(
    cm_norm,
    annot=True,
    fmt=".2f",
    cmap="Greens",
    xticklabels=class_names,
    yticklabels=class_names
)

plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Normalized Confusion Matrix")

plt.tight_layout()

plt.savefig("normalized_confusion_matrix.png",dpi=300)

plt.show()

# %%
y_test_bin = label_binarize(y_true, classes=np.arange(len(class_names)))

plt.figure(figsize=(8,6))

for i in range(len(class_names)):

    fpr, tpr, _ = roc_curve(
        y_test_bin[:,i],
        predictions[:,i]
    )

    roc_auc = auc(fpr,tpr)

    plt.plot(
        fpr,
        tpr,
        label=f"{class_names[i]} (AUC={roc_auc:.2f})"
    )

plt.plot([0,1],[0,1],'k--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

plt.title("ROC Curve")

plt.legend()

plt.grid()

plt.savefig("roc_curve.png",dpi=300)

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.plot(history.history['accuracy'],label='Train')
plt.plot(history.history['val_accuracy'],label='Validation')

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training Accuracy")

plt.legend()

plt.savefig("training_accuracy.png",dpi=300)

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.plot(history.history['loss'],label='Train')
plt.plot(history.history['val_loss'],label='Validation')

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss")

plt.legend()

plt.savefig("training_loss.png",dpi=300)

plt.show()
